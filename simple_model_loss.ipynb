# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loss1 = np.load('./models/loss_simple_model_0.0001-0.0001.npy')

# %%
loss2 = np.load('./models/loss_simple_model_0.0001-0.001.npy')

# %%
plt.plot(np.log(loss1))
plt.title('loss with lr = 0.0001')
plt.show()

# %%
plt.title('loss with lr = 0.001')
plt.plot(np.log(loss2))
plt.show()
